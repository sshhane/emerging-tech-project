# %% [markdown]
# # 2. Iris dataset notebook:
# #### A jupyter notebook explaining the famous iris data set including the difficulty in writing an algorithm to separate the three classes of iris based on the variables in the dataset.

# %% [markdown]
# ## Iris Flowers
# <img src="img/iris.jpeg">
# An Iris is a species of flower from the Iridaceae family of plants.  There are three sub-species of Iris (Setosa, Virginica, Versicolour) each with varying petal and sepal length.
#
# ## Iris Dataset
# The Iris dataset is comprised of 50 of each of the three variants and includes their measurements of petal and sepal length and width.  It is quite popular in computer science and is used mainly for testing machine learning algorithms and neural networks.
#
# <img src="img/petalSepal.jpg">
#
#
# ## Pandas
# https://pandas.pydata.org
#
# Pandas is an open source library written for python.  In this notebook I will be using pandas to manipulate andanalyse the Iris Dataset.

# %% [markdown]
# ### Import pandas

# %%
import pandas as pd

# %% [markdown]
# ### Loading the iris dataset
# Here I am loading the dataset from embeded github link

# %%
iris = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

# %% [markdown]
# ### Displaying the dataset

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Seaborn
# > Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# I will be using this package to dispalay the iris dataset in graphical form.
#
# ### Importing seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### Plot

# %%
sns.pairplot(iris, hue='species')
# sns.pairplot(iris, hue="sepal_length")

# %% [markdown]
# ## Seperating the species
# Finding a clear way to distinguish between the three species can be tricky.  Below, you can see that the setosa petal length and width readings are drastically seperated from the other two species, making the setosa easy to identify.  However these graphs also show that the seperation between versicolor and virginica is not as clean-cut and simple.
#
# ### Petal

# %%
sns.violinplot(x='species',y='petal_length',data=iris)

# %%
sns.violinplot(x='species',y='petal_width',data=iris)

# %% [markdown]
# ### Sepal
# The seperation between versicolor and virginica, or lack thereof is also quite plevelant in the sepal length and width

# %%
sns.violinplot(x='species',y='sepal_length',data=iris)

# %%
sns.violinplot(x='species',y='sepal_width',data=iris)

# %% [markdown]
# ## Sources
# http://archive.ics.uci.edu/ml/datasets/Iris
#
# https://www.techopedia.com/definition/32880/iris-flower-data-set
#
# https://seaborn.pydata.org/
#
# https://www.youtube.com/watch?v=ywIWUfjPCyY
#
# https://medium.com/codebagng/basic-analysis-of-the-iris-data-set-using-python-2995618a6342
