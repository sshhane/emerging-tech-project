# %% [markdown]
# # 1. Numpy Random notebook:
# #### A jupyter notebook explaining the con-cepts behind and the use of the numpy random package, including plots of the various distributions.
#
# ### What is Numpy?
# Before I get into how to use numpy.random, I would first like to give a brief overview of the package.  Numpy is a package for python that can run matrix operations at a very high efficiency.
#
# From the numpy docs:
#
# >_"NumPy is the fundamental package for scientific computing in Python. It is a Python library that provides a multidimensional array object, various derived objects (such as masked arrays and matrices), and an assortment of routines for fast operations on arrays, including mathematical, logical, shape manipulation, sorting, selecting, I/O, discrete Fourier transforms, basic linear algebra, basic statistical operations, random simulation and much more."_

# %% [markdown]
# ### What is Numpy Random?
# Numpy random is used for random numerical sampling.  It

# %% [markdown]
# To get started using the numpy package, it must first be imported at the top of your script

# %%
import numpy as np

# %% [markdown]
# ### Numpy.rand
# Genorates random values in a given shape.

# %% [markdown]
# #### Single float

# %%
np.random.rand()
# Out:
# 0.6140817109469328

# %% [markdown]
# #### 1D array

# %%
np.random.rand(5)
# Out:
# array([0.30370215, 0.47313736, 0.9086818 , 0.60221679, 0.02326417])

# %% [markdown]
# #### 2D array

# %%
np.random.rand(2, 2)
# Out:
# array([[0.06770768, 0.98752716],
#        [0.69414936, 0.76710488]])

# %% [markdown]
# #### Multi dimensional array
# It is also possible to genorate multi-dimensional arrays

# %%
np.random.rand(2,2,2,2)
# Out:
# array([[[[0.04176441, 0.01364027],
#          [0.68024578, 0.5963382 ]],
#
#         [[0.44056352, 0.05985609],
#          [0.07493153, 0.46570589]]],
#
#
#        [[[0.32492955, 0.20839662],
#          [0.24124   , 0.54119647]],
#
#         [[0.22570513, 0.79024016],
#          [0.1384933 , 0.89646104]]]])

# %%
import matplotlib.pyplot as plt
plt.plot(np.random.rand(3,5))
plt.show()

# %% [markdown]
# ### numpy.randn
# Return a sample (or samples) from the “standard normal” distribution.
# #### Usage:
# np.randn(d0, d1, ..., dn)

# %% [markdown]
# ### numpy.random_sample()
# Return random floats in the half-open interval [0.0, 1.0).
# #### Usage:
# np.random_sample([size])

# %% [markdown]
# ### numpy.normal
# Draw random samples from a normal (Gaussian) distribution.
# #### Usage:
# np.normal([loc, scale, size])

# %% [markdown]
# ### numpy.standard_normal
# Draw samples from a standard Normal distribution (mean=0, stdev=1).
# #### Usage:
# np.standard_normal([size])

# %%
x = np.arange(0.0, 10.0, 0.01)
y = 3.0 * x + 1.0
noise = np.random.normal(0.0, 1.0, len(x))

plt.plot(x, y + noise, 'r.', label="Actual")
plt.plot(x, y, 'b-', label="Model")

plt.title("Simple plot")
plt.xlabel("Weight")
plt.ylabel("Mass")
plt.legend()

plt.show()

# %%
plt.subplot(1, 2, 1)
x = np.random.normal(0.0, 1.0, 10000)
plt.hist(x)

plt.subplot(1, 2, 2)
x = np.random.uniform(-3.0, 3.0, 10000)
plt.hist(x)

plt.show()

# %%
x = np.arange(1.0, 100.0, 0.1)

plt.plot(x, x**2, 'g-', label="x^2")
plt.plot(x, x**3, 'b-', label="x^3")
plt.plot(x, x**4, 'r-', label="x^4")
plt.plot(x, 2**x, 'k-', label="2^x")

plt.legend()

plt.show()

# %%
x = np.random.uniform(0.0, 10.0, 100)
y = np.random.uniform(0.0, 100.0, 100)
z = np.random.normal(100.0, 40.0, 100)
c = np.random.randint(0, 20, 100)

plt.scatter(x, y, c=c, s=z)

plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
x = np.arange(-2.0 * np.pi, 2.0 * np.pi, 0.1)

plt.plot(x, np.sin(x), 'g.')
plt.plot(x, np.cos(x), 'b.')

plt.show()
